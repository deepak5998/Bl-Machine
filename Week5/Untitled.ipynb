# %%
import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

# %%
ar1 = np.array(np.random.rand(100))
ar2 = np.array(np.random.rand(100))
ar3 = np.array(np.random.rand(100))
fig, ax = plt.subplots(3, figsize=(15,10))
ax[0].plot(ar1,ar2)
ax[1].plot(ar2,ar1)
ax[2].plot(ar3,ar1)
plt.show()
